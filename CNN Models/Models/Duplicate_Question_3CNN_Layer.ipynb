# %%
from keras.preprocessing import sequence
from keras.preprocessing import text
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, LSTM
from keras.layers import Conv1D, Flatten
from keras.preprocessing import text
from keras.models import Sequential,Model
from keras.layers import Dense ,Activation,MaxPool1D,Conv1D,Flatten,Dropout,Activation,Dropout,Input,Lambda,concatenate
from keras.utils import np_utils
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
import nltk
import csv
import pandas as pd

from keras.preprocessing import text as keras_text, sequence as keras_seq

# %%
data = pd.read_csv('drive/My Drive/ML Internship IIIT Dharwad/train.csv')
pd.set_option('display.max_colwidth',80)
data.head()
# Out:
#    id  ...  is_duplicate
# 0   0  ...             0
# 1   1  ...             0
# 2   2  ...             0
# 3   3  ...             0
# 4   4  ...             0
#
# [5 rows x 6 columns]

# %%
data.shape
# Out:
# (404290, 6)

# %%
print(data.dtypes)
print(data['question1'].dtypes)
print(data['question2'].dtypes)
type(data['question1'])
# Out:
# id               int64
# qid1             int64
# qid2             int64
# question1       object
# question2       object
# is_duplicate     int64
# dtype: object
# object
# object
# pandas.core.series.Series

# %% [markdown]
# # Setting target or labelfor each input

# %%
label_oneDimension=data['is_duplicate']

# %%
label_oneDimension.head(2)
# Out:
# 0    0
# 1    0
# Name: is_duplicate, dtype: int64

# %%
import numpy as np
from keras.utils.np_utils import to_categorical
label_twoDimension = to_categorical(data['is_duplicate'], num_classes=2)

# %%
label_twoDimension[0:1]
# Out:
# array([[1., 0.]], dtype=float32)

# %%
question_one=data['question1'].astype(str)
print(question_one.head())
# Out:
# 0              What is the step by step guide to invest in share market in india?
# 1                             What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 2       How can I increase the speed of my internet connection while using a VPN?
# 3                              Why am I mentally very lonely? How can I solve it?
# 4    Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
# Name: question1, dtype: object

# %%
question_two=data['question2'].astype(str)
print(question_two.head())
# Out:
# 0                          What is the step by step guide to invest in share market?
# 1    What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) d...
# 2                        How can Internet speed be increased by hacking through DNS?
# 3                  Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# 4                                            Which fish would survive in salt water?
# Name: question2, dtype: object

# %% [markdown]
# # Reading test data and preprocessing

# %%
#Data reading
'''
data_test = pd.read_csv('drive/My Drive/Summer Internship 2020 July/My Test File/Sunil/test.csv')
data_test_sample=data_test.dropna()
#data_test_sample=data_test_sample.head(100)
data_test_sample.head()
'''
# Out:
# "\ndata_test = pd.read_csv('drive/My Drive/Summer Internship 2020 July/My Test File/Sunil/test.csv')\ndata_test_sample=data_test.dropna()\n#data_test_sample=data_test_sample.head(100)\ndata_test_sample.head()\n"

# %%
'''
question_one_test=data_test_sample['question1'].astype(str)
print(question_one_test.head())
'''
# Out:
# "\nquestion_one_test=data_test_sample['question1'].astype(str)\nprint(question_one_test.head())\n"

# %%
'''
question_two_test=data_test_sample['question2'].astype(str)
print(question_two_test.head())
'''
# Out:
# "\nquestion_two_test=data_test_sample['question2'].astype(str)\nprint(question_two_test.head())\n"

# %% [markdown]
# # Fitting text on a single tokenized object

# %%
from keras.preprocessing.text import Tokenizer
tok_all = Tokenizer(char_level = False)
tok_all.fit_on_texts(question_one+question_two)
#tok_all.fit_on_texts(question_one+question_two+question_one_test+question_two_test)

# %%
vocabulary_all=len(tok_all.word_counts)
print(vocabulary_all)
# Out:
# 96494

# %% [markdown]
# # Train data Sequencing and Encoding

# %%
#Encoding question 1
encoded_q1=tok_all.texts_to_sequences(question_one)
print(question_one[0])
encoded_q1[0]
# Out:
# What is the step by step guide to invest in share market in india?
# [2, 3, 1, 1221, 57, 1221, 2581, 7, 575, 8, 763, 383, 8, 35]

# %%
#Encoding question 2
encoded_q2=tok_all.texts_to_sequences(question_two)
print(question_two[0])
encoded_q2[0]
# Out:
# What is the step by step guide to invest in share market?
# [2, 3, 1, 1221, 57, 1221, 2581, 7, 575, 8, 763, 383]

# %% [markdown]
# # Pre-Padding on Train data

# %%
#####Padding encoded sequence of words
from keras.preprocessing import sequence
max_length=100
padded_docs_q1 = sequence.pad_sequences(encoded_q1, maxlen=max_length, padding='pre')

# %%
#####Padding encoded sequence of words
from keras.preprocessing import sequence
max_length=100
padded_docs_q2 = sequence.pad_sequences(encoded_q2, maxlen=max_length, padding='pre')

# %% [markdown]
# # Encoding on Test data

# %%
'''
#Encoding question 1
encoded_q1_test=tok_all.texts_to_sequences(question_one_test)
print(question_one_test[0])
encoded_q1_test[0]
'''
# Out:
# '\n#Encoding question 1\nencoded_q1_test=tok_all.texts_to_sequences(question_one_test)\nprint(question_one_test[0])\nencoded_q1_test[0]\n'

# %%
'''#Encoding question 1
encoded_q2_test=tok_all.texts_to_sequences(question_two_test)
print(question_two_test[0])
encoded_q2_test[0]'''
# Out:
# '#Encoding question 1\nencoded_q2_test=tok_all.texts_to_sequences(question_two_test)\nprint(question_two_test[0])\nencoded_q2_test[0]'

# %% [markdown]
# # Pre-Padding on test data

# %%
'''#####Padding encoded sequence of words
padded_docs_q1_test = sequence.pad_sequences(encoded_q1_test, maxlen=max_length, padding='pre')
padded_docs_q2_test = sequence.pad_sequences(encoded_q2_test, maxlen=max_length, padding='pre')'''
# Out:
# "#####Padding encoded sequence of words\npadded_docs_q1_test = sequence.pad_sequences(encoded_q1_test, maxlen=max_length, padding='pre')\npadded_docs_q2_test = sequence.pad_sequences(encoded_q2_test, maxlen=max_length, padding='pre')"

# %% [markdown]
# # Reading Embedding Vector from Glove

# %%
import os
import numpy as np

# %%
embeddings_index = {}
f = open('drive/My Drive/ML Internship IIIT Dharwad/Copy of glove.6B.300d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((vocabulary_all+1, 300))
for word, i in tok_all.word_index.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embedding_matrix[i] = embedding_vector

# %% [markdown]
# # Defining Input Shape for Model

# %%
Question1_shape= Input(shape=[max_length])
Question1_shape.shape
# Out:
# TensorShape([None, 100])

# %%
Question2_shape= Input(shape=[max_length])
Question2_shape.shape
# Out:
# TensorShape([None, 100])

# %% [markdown]
# # Embedding Layer

# %%
Embedding_Layer = Embedding(vocabulary_all+1,300,weights=[embedding_matrix], input_length=max_length, trainable=False)

# %% [markdown]
# # CNN Network

# %%
CNN3_network=Sequential([Embedding_Layer,
                        Conv1D(32,3,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Flatten(),
                       Dense(128,activation="linear"),
                       Dropout(0.3)
                       
                       ])

# %% [markdown]
# # Printing Model summary

# %%
CNN3_network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 300)          28948500
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 100, 32)           28832
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100, 32)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 50, 64)            10304
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50, 64)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 25, 64)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 25, 64)            20544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 25, 64)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 12, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               98432
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# =================================================================
# Total params: 29,106,612
# Trainable params: 158,112
# Non-trainable params: 28,948,500
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(CNN3_network, to_file='CNN3_network.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # create siamese network from CNN model and store output feature vectors

# %%
Question1_CNN_feature=CNN3_network(Question1_shape)
Question2_CNN_feature=CNN3_network(Question2_shape)

# %% [markdown]
# # Adding and multiplying features obtained from Siamese CNN network

# %%
from keras import backend as K
from keras.optimizers import Adam

# %%
lamda_function=Lambda(lambda tensor:K.abs(tensor[0]-tensor[1]),name="Absolute_distance")
abs_distance_vector=lamda_function([Question1_CNN_feature,Question2_CNN_feature])

lamda_function2=Lambda(lambda tensor:K.abs(tensor[0]*tensor[1]),name="Hamadard_multiplication")
hamadard_vector=lamda_function2([Question1_CNN_feature,Question2_CNN_feature])

# %% [markdown]
# # Adding abs_distance_vector and hamadard_vector

# %%
from keras.layers import Add

# %%
added_vecotr = Add()([abs_distance_vector, hamadard_vector])

# %% [markdown]
# # Final Model prediction

# %%
predict=Dense(2,activation="sigmoid")(added_vecotr)

# %% [markdown]
# # Creating sequential model using Model() class and compilation

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score
Siamese3_Network=Model(inputs=[Question1_shape,Question2_shape],outputs=predict)
Siamese3_Network.compile(loss = "binary_crossentropy", optimizer=Adam(lr=0.00003), metrics=["accuracy"])

# %%
Siamese3_Network.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 128)          29106612    input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# Absolute_distance (Lambda)      (None, 128)          0           sequential_1[0][0]
#                                                                  sequential_1[1][0]
# __________________________________________________________________________________________________
# Hamadard_multiplication (Lambda (None, 128)          0           sequential_1[0][0]
#                                                                  sequential_1[1][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128)          0           Absolute_distance[0][0]
#                                                                  Hamadard_multiplication[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            258         add_1[0][0]
# ==================================================================================================
# Total params: 29,106,870
# Trainable params: 158,370
# Non-trainable params: 28,948,500
# __________________________________________________________________________________________________

# %% [markdown]
# # Plot model

# %%
from keras.utils import plot_model
plot_model(Siamese3_Network, to_file='Siamese3_Network.png',show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Setting hyperparameter for training

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
earlystopper = EarlyStopping(patience=8, verbose=1)
#checkpointer = ModelCheckpoint(filepath = 'cnn_model_one_.{epoch:02d}-{val_loss:.6f}.hdf5',
 #                              verbose=1,
 #                              save_best_only=True, save_weights_only = True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9,
                              patience=2, min_lr=0.00001, verbose=1)

# %% [markdown]
# # Data split into train and validation set

# %%
# Splitting data into train and test
from sklearn.model_selection import train_test_split
q1_train, q1_val,q2_train, q2_val, label_train, label_val, label_oneD_train, label_oneD_val = train_test_split(padded_docs_q1,padded_docs_q2, label_twoDimension, label_oneDimension, test_size=0.30,
random_state=42)

# %% [markdown]
# # Model fitting or training

# %%
history = Siamese3_Network.fit([q1_train,q2_train],label_train,
                    batch_size=256,epochs=100,validation_data=([q1_val,q2_val],label_val),callbacks=[earlystopper, reduce_lr])
# Out:
# Epoch 1/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.6250 - accuracy: 0.6388 - val_loss: 0.6288 - val_accuracy: 0.6470
# Epoch 2/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5936 - accuracy: 0.6809 - val_loss: 0.6134 - val_accuracy: 0.6915
# Epoch 3/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5746 - accuracy: 0.7009 - val_loss: 0.6001 - val_accuracy: 0.7015
# Epoch 4/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5630 - accuracy: 0.7101 - val_loss: 0.5937 - val_accuracy: 0.7078
# Epoch 5/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5548 - accuracy: 0.7156 - val_loss: 0.5880 - val_accuracy: 0.7155
# Epoch 6/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5482 - accuracy: 0.7207 - val_loss: 0.5835 - val_accuracy: 0.7177
# Epoch 7/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5425 - accuracy: 0.7253 - val_loss: 0.5783 - val_accuracy: 0.7177
# Epoch 8/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5383 - accuracy: 0.7284 - val_loss: 0.5739 - val_accuracy: 0.7209
# Epoch 9/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5343 - accuracy: 0.7315 - val_loss: 0.5696 - val_accuracy: 0.7232
# Epoch 10/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5302 - accuracy: 0.7345 - val_loss: 0.5669 - val_accuracy: 0.7267
# Epoch 11/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5270 - accuracy: 0.7370 - val_loss: 0.5639 - val_accuracy: 0.7265
# Epoch 12/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5242 - accuracy: 0.7391 - val_loss: 0.5590 - val_accuracy: 0.7317
# Epoch 13/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5203 - accuracy: 0.7421 - val_loss: 0.5581 - val_accuracy: 0.7317
# Epoch 14/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.5184 - accuracy: 0.7426 - val_loss: 0.5556 - val_accuracy: 0.7312
# Epoch 15/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5163 - accuracy: 0.7444 - val_loss: 0.5561 - val_accuracy: 0.7333
# Epoch 16/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5132 - accuracy: 0.7468 - val_loss: 0.5503 - val_accuracy: 0.7379
# Epoch 17/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5115 - accuracy: 0.7477 - val_loss: 0.5513 - val_accuracy: 0.7336
# Epoch 18/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5099 - accuracy: 0.7485 - val_loss: 0.5478 - val_accuracy: 0.7378
# Epoch 19/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5072 - accuracy: 0.7505 - val_loss: 0.5460 - val_accuracy: 0.7391
# Epoch 20/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5057 - accuracy: 0.7524 - val_loss: 0.5448 - val_accuracy: 0.7423
# Epoch 21/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5036 - accuracy: 0.7532 - val_loss: 0.5424 - val_accuracy: 0.7433
# Epoch 22/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5029 - accuracy: 0.7539 - val_loss: 0.5413 - val_accuracy: 0.7450
# Epoch 23/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5005 - accuracy: 0.7552 - val_loss: 0.5409 - val_accuracy: 0.7436
# Epoch 24/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4986 - accuracy: 0.7560 - val_loss: 0.5395 - val_accuracy: 0.7423
# Epoch 25/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4974 - accuracy: 0.7565 - val_loss: 0.5380 - val_accuracy: 0.7405
# Epoch 26/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4964 - accuracy: 0.7585 - val_loss: 0.5357 - val_accuracy: 0.7421
# Epoch 27/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4947 - accuracy: 0.7586 - val_loss: 0.5344 - val_accuracy: 0.7472
# Epoch 28/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4932 - accuracy: 0.7593 - val_loss: 0.5331 - val_accuracy: 0.7463
# Epoch 29/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4918 - accuracy: 0.7605 - val_loss: 0.5322 - val_accuracy: 0.7438
# Epoch 30/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4904 - accuracy: 0.7610 - val_loss: 0.5285 - val_accuracy: 0.7496
# Epoch 31/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4898 - accuracy: 0.7611 - val_loss: 0.5287 - val_accuracy: 0.7472
# Epoch 32/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4878 - accuracy: 0.7629 - val_loss: 0.5266 - val_accuracy: 0.7478
# Epoch 33/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4870 - accuracy: 0.7630 - val_loss: 0.5242 - val_accuracy: 0.7509
# Epoch 34/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4858 - accuracy: 0.7639 - val_loss: 0.5235 - val_accuracy: 0.7518
# Epoch 35/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4844 - accuracy: 0.7649 - val_loss: 0.5236 - val_accuracy: 0.7482
# Epoch 36/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4833 - accuracy: 0.7656
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 2.699999931792263e-05.
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.4833 - accuracy: 0.7656 - val_loss: 0.5244 - val_accuracy: 0.7481
# Epoch 37/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4817 - accuracy: 0.7665 - val_loss: 0.5182 - val_accuracy: 0.7542
# Epoch 38/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4802 - accuracy: 0.7671 - val_loss: 0.5159 - val_accuracy: 0.7537
# Epoch 39/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4801 - accuracy: 0.7668 - val_loss: 0.5159 - val_accuracy: 0.7532
# Epoch 40/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4792 - accuracy: 0.7687
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.4300000040966553e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4792 - accuracy: 0.7687 - val_loss: 0.5160 - val_accuracy: 0.7527
# Epoch 41/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4774 - accuracy: 0.7691 - val_loss: 0.5150 - val_accuracy: 0.7546
# Epoch 42/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4769 - accuracy: 0.7699 - val_loss: 0.5158 - val_accuracy: 0.7554
# Epoch 43/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4757 - accuracy: 0.7703 - val_loss: 0.5131 - val_accuracy: 0.7547
# Epoch 44/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4751 - accuracy: 0.7703 - val_loss: 0.5114 - val_accuracy: 0.7557
# Epoch 45/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4743 - accuracy: 0.7718 - val_loss: 0.5129 - val_accuracy: 0.7541
# Epoch 46/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4726 - accuracy: 0.7721 - val_loss: 0.5084 - val_accuracy: 0.7593
# Epoch 47/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4721 - accuracy: 0.7723 - val_loss: 0.5122 - val_accuracy: 0.7519
# Epoch 48/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4711 - accuracy: 0.7739 - val_loss: 0.5069 - val_accuracy: 0.7604
# Epoch 49/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4710 - accuracy: 0.7732 - val_loss: 0.5081 - val_accuracy: 0.7575
# Epoch 50/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4702 - accuracy: 0.7735
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.1869999545742758e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4702 - accuracy: 0.7735 - val_loss: 0.5099 - val_accuracy: 0.7555
# Epoch 51/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4686 - accuracy: 0.7743 - val_loss: 0.5064 - val_accuracy: 0.7560
# Epoch 52/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4684 - accuracy: 0.7752 - val_loss: 0.5058 - val_accuracy: 0.7592
# Epoch 53/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4675 - accuracy: 0.7761 - val_loss: 0.5051 - val_accuracy: 0.7592
# Epoch 54/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4666 - accuracy: 0.7751 - val_loss: 0.5018 - val_accuracy: 0.7625
# Epoch 55/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4654 - accuracy: 0.7766 - val_loss: 0.5025 - val_accuracy: 0.7579
# Epoch 56/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4649 - accuracy: 0.7765 - val_loss: 0.5015 - val_accuracy: 0.7593
# Epoch 57/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4641 - accuracy: 0.7766 - val_loss: 0.5013 - val_accuracy: 0.7597
# Epoch 58/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4637 - accuracy: 0.7774 - val_loss: 0.5003 - val_accuracy: 0.7615
# Epoch 59/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4631 - accuracy: 0.7774 - val_loss: 0.5000 - val_accuracy: 0.7606
# Epoch 60/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4626 - accuracy: 0.7790 - val_loss: 0.4997 - val_accuracy: 0.7604
# Epoch 61/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4619 - accuracy: 0.7784 - val_loss: 0.5036 - val_accuracy: 0.7558
# Epoch 62/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4616 - accuracy: 0.7784 - val_loss: 0.4964 - val_accuracy: 0.7632
# Epoch 63/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4610 - accuracy: 0.7791 - val_loss: 0.4986 - val_accuracy: 0.7584
# Epoch 64/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4603 - accuracy: 0.7801 - val_loss: 0.4949 - val_accuracy: 0.7636
# Epoch 65/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4593 - accuracy: 0.7800 - val_loss: 0.4945 - val_accuracy: 0.7656
# Epoch 66/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4593 - accuracy: 0.7803 - val_loss: 0.4951 - val_accuracy: 0.7632
# Epoch 67/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4586 - accuracy: 0.7802
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.9682998936332296e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4586 - accuracy: 0.7802 - val_loss: 0.4963 - val_accuracy: 0.7636
# Epoch 68/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4582 - accuracy: 0.7811 - val_loss: 0.4953 - val_accuracy: 0.7646
# Epoch 69/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.4579 - accuracy: 0.7809 - val_loss: 0.4932 - val_accuracy: 0.7651
# Epoch 70/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4573 - accuracy: 0.7805 - val_loss: 0.4927 - val_accuracy: 0.7668
# Epoch 71/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4563 - accuracy: 0.7817 - val_loss: 0.4949 - val_accuracy: 0.7632
# Epoch 72/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4563 - accuracy: 0.7817
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.7714698878990023e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4562 - accuracy: 0.7817 - val_loss: 0.4938 - val_accuracy: 0.7631
# Epoch 73/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4553 - accuracy: 0.7821 - val_loss: 0.4915 - val_accuracy: 0.7662
# Epoch 74/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4553 - accuracy: 0.7818 - val_loss: 0.4917 - val_accuracy: 0.7654
# Epoch 75/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4549 - accuracy: 0.7831
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.5943229482218157e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4548 - accuracy: 0.7831 - val_loss: 0.4933 - val_accuracy: 0.7629
# Epoch 76/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4548 - accuracy: 0.7824 - val_loss: 0.4924 - val_accuracy: 0.7652
# Epoch 77/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4539 - accuracy: 0.7836 - val_loss: 0.4913 - val_accuracy: 0.7657
# Epoch 78/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4537 - accuracy: 0.7832 - val_loss: 0.4936 - val_accuracy: 0.7629
# Epoch 79/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4536 - accuracy: 0.7835 - val_loss: 0.4908 - val_accuracy: 0.7657
# Epoch 80/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.4525 - accuracy: 0.7846 - val_loss: 0.4913 - val_accuracy: 0.7648
# Epoch 81/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4529 - accuracy: 0.7842 - val_loss: 0.4887 - val_accuracy: 0.7663
# Epoch 82/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4524 - accuracy: 0.7843 - val_loss: 0.4918 - val_accuracy: 0.7653
# Epoch 83/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4521 - accuracy: 0.7840
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.4348906370287296e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4521 - accuracy: 0.7841 - val_loss: 0.4888 - val_accuracy: 0.7678
# Epoch 84/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4511 - accuracy: 0.7844 - val_loss: 0.4907 - val_accuracy: 0.7656
# Epoch 85/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4509 - accuracy: 0.7847 - val_loss: 0.4879 - val_accuracy: 0.7679
# Epoch 86/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4511 - accuracy: 0.7850 - val_loss: 0.4914 - val_accuracy: 0.7638
# Epoch 87/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4510 - accuracy: 0.7850 - val_loss: 0.4872 - val_accuracy: 0.7690
# Epoch 88/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4502 - accuracy: 0.7846 - val_loss: 0.4879 - val_accuracy: 0.7678
# Epoch 89/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4499 - accuracy: 0.7853
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.2914015405840473e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4499 - accuracy: 0.7853 - val_loss: 0.4894 - val_accuracy: 0.7663
# Epoch 90/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4486 - accuracy: 0.7867 - val_loss: 0.4879 - val_accuracy: 0.7674
# Epoch 91/100
# 1103/1106 [============================>.] - ETA: 0s - loss: 0.4492 - accuracy: 0.7859
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.1622613783401903e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4492 - accuracy: 0.7859 - val_loss: 0.4889 - val_accuracy: 0.7664
# Epoch 92/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4497 - accuracy: 0.7857 - val_loss: 0.4882 - val_accuracy: 0.7665
# Epoch 93/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4490 - accuracy: 0.7861
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.0460352405061712e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4489 - accuracy: 0.7862 - val_loss: 0.4872 - val_accuracy: 0.7690
# Epoch 94/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4483 - accuracy: 0.7869 - val_loss: 0.4882 - val_accuracy: 0.7674
# Epoch 95/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4486 - accuracy: 0.7865
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4485 - accuracy: 0.7865 - val_loss: 0.4879 - val_accuracy: 0.7671
# Epoch 00095: early stopping

# %% [markdown]
# # Model Prediction

# %%
Siamese3_Network_predictions = Siamese3_Network.predict([q1_val,q2_val])
#Siamese3_Network_predictions = Siamese3_Network.predict([padded_docs_q1_test,padded_docs_q2_test])

# %%
#Siamese3_Network_predictions_testData = Siamese3_Network.predict([padded_docs_q1_test,padded_docs_q1_test])

# %% [markdown]
# # Log loss

# %%
from sklearn.metrics import log_loss
log_loss_val= log_loss(label_val,Siamese3_Network_predictions)
log_loss_val
# Out:
# 0.48808141624983215

# %% [markdown]
# # Classification report

# %%
predictions = np.zeros_like(Siamese3_Network_predictions)
predictions[np.arange(len(Siamese3_Network_predictions)), Siamese3_Network_predictions.argmax(1)] = 1

# %%
predictionInteger=(np.argmax(predictions, axis=1))
#print('np.argmax(a, axis=1): {0}'.format(np.argmax(predictions, axis=1)))
predictionInteger
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import classification_report
print(classification_report(label_val,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.83     76350
#            1       0.80      0.49      0.61     44937
#
#    micro avg       0.77      0.77      0.77    121287
#    macro avg       0.78      0.71      0.72    121287
# weighted avg       0.77      0.77      0.75    121287
#  samples avg       0.77      0.77      0.77    121287

# %%
from sklearn.metrics import precision_recall_fscore_support
print ("Precision, Recall, F1_score : macro ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='macro'))
print ("Precision, Recall, F1_score : micro ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='micro'))
print ("Precision, Recall, F1_score : weighted ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='weighted'))
# Out:
# Precision, Recall, F1_score : macro  (0.7797176905817067, 0.7106232751173626, 0.7221837460752423, None)
# Precision, Recall, F1_score : micro  (0.7671308549143766, 0.7671308549143766, 0.7671308549143766, None)
# Precision, Recall, F1_score : weighted  (0.7737411458650805, 0.7671308549143766, 0.751125501327138, None)

# %% [markdown]
# # Final train and val loss

# %%
min_val_loss = min(history.history["val_loss"])
min_train_loss = min(history.history["loss"])
max_val_acc = max(history.history["val_accuracy"])
max_train_acc = max(history.history["accuracy"])
print("min_train_loss=%g, min_val_loss=%g, max_train_acc=%g, max_val_acc=%g" % (min_train_loss,min_val_loss,max_train_acc,max_val_acc))
# Out:
# min_train_loss=0.448251, min_val_loss=0.487227, max_train_acc=0.786857, max_val_acc=0.769027

# %% [markdown]
# # Plot epoch Vs loss

# %%
from matplotlib import pyplot as plt
plt.plot(history.history["loss"],color = 'red', label = 'train_loss')
plt.plot(history.history["val_loss"],color = 'blue', label = 'val_loss')
plt.title('Loss Visualisation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('3Layer_CNN_lossPlot_siamese.pdf',dpi=1000)

from google.colab import files
files.download('3Layer_CNN_lossPlot_siamese.pdf')

# %% [markdown]
# # Plot Epoch Vs Accuracy

# %%
plt.plot(history.history["accuracy"],color = 'red', label = 'train_accuracy')
plt.plot(history.history["val_accuracy"],color = 'blue', label = 'val_accuracy')
plt.title('Accuracy Visualisation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('3Layer_CNN_accuracyPlot_siamese.pdf',dpi=1000)
files.download('3Layer_CNN_accuracyPlot_siamese.pdf')

# %% [markdown]
# # Area Under Curve- ROC

# %%
#pred_test = Siamese3_Network.predict([padded_docs_q1_test,padded_docs_q2_test])
pred_train = Siamese3_Network.predict([q1_train,q2_train])
pred_val = Siamese3_Network.predict([q1_val,q2_val])

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

def plot_AUC_ROC(y_true, y_pred):
    n_classes = 2 #change this value according to class value

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
############################################################################################
    lw = 2
    # Compute macro-average ROC curve and ROC area

    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure()
    
    plt.plot(fpr["micro"], tpr["micro"],
            label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
            color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
            label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
            color='navy', linestyle=':', linewidth=4)
    
    colors = cycle(['aqua', 'darkorange'])
    #classes_list1 = ["DE","NE","DK"]
    classes_list1 = ["Non-duplicate","Duplicate"]
    for i, color,c in zip(range(n_classes), colors,classes_list1):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                label='{0} (AUC = {1:0.2f})'
                ''.format(c, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.legend(loc="lower right")
    #plt.show()
    plt.savefig('3Layer_CNN_RocPlot_siamese.pdf',dpi=1000)
    files.download('3Layer_CNN_RocPlot_siamese.pdf')

    # Plot of a ROC curve for a specific class
    '''
    plt.figure()
    lw = 2
    plt.plot(fpr[0], tpr[0], color='darkorange',
            lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[0])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
    '''

# %%
plot_AUC_ROC(label_val,pred_val)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score

# %%
auc_val = roc_auc_score(label_val,pred_val)
accuracy_val = accuracy_score(label_val,pred_val>0.5)
auc_train = roc_auc_score(label_train,pred_train)
accuracy_train = accuracy_score(label_train,pred_train>0.5)

print("auc_train=%g, auc_val=%g, accuracy_train=%g, accuracy_val=%g" % (auc_train, auc_val, accuracy_train, accuracy_val))
# Out:
# auc_train=0.86895, auc_val=0.844106, accuracy_train=0.784508, accuracy_val=0.765309

# %%
'''
fpr_train, tpr_train, thresholds_train = roc_curve(label_train,pred_train)
fpr_test, tpr_test, thresholds_test = roc_curve(label_val,pred_val)

#fpr_train, tpr_train, thresholds_train = roc_curve(label_oneD_train,pred_train_final)
#fpr_test, tpr_test, thresholds_test = roc_curve(label_oneD_val,pred_val_final)

plt.plot(fpr_train,tpr_train, color="blue", label="train roc, auc=%g" % (auc_train,))
plt.plot(fpr_test,tpr_test, color="green", label="val roc, auc=%g" % (auc_val,))

plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')
plt.savefig('AUC_CURVE_cnn4.pdf',dpi=1000)
#files.download('AUC_CURVE_cnn4.pdf')
'''
# Out:
# '\nfpr_train, tpr_train, thresholds_train = roc_curve(label_train,pred_train)\nfpr_test, tpr_test, thresholds_test = roc_curve(label_val,pred_val)\n\n#fpr_train, tpr_train, thresholds_train = roc_curve(label_oneD_train,pred_train_final)\n#fpr_test, tpr_test, thresholds_test = roc_curve(label_oneD_val,pred_val_final)\n\nplt.plot(fpr_train,tpr_train, color="blue", label="train roc, auc=%g" % (auc_train,))\nplt.plot(fpr_test,tpr_test, color="green", label="val roc, auc=%g" % (auc_val,))\n\nplt.plot([0,1], [0,1], color=\'orange\', linestyle=\'--\')\n\nplt.xticks(np.arange(0.0, 1.1, step=0.1))\nplt.xlabel("Flase Positive Rate", fontsize=15)\n\nplt.yticks(np.arange(0.0, 1.1, step=0.1))\nplt.ylabel("True Positive Rate", fontsize=15)\n\nplt.title(\'ROC Curve Analysis\', fontweight=\'bold\', fontsize=15)\nplt.legend(prop={\'size\':13}, loc=\'lower right\')\nplt.savefig(\'AUC_CURVE_cnn4.pdf\',dpi=1000)\n#files.download(\'AUC_CURVE_cnn4.pdf\')\n'
