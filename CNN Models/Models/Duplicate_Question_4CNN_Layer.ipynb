# %%
from keras.preprocessing import sequence
from keras.preprocessing import text
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, LSTM
from keras.layers import Conv1D, Flatten
from keras.preprocessing import text
from keras.models import Sequential,Model
from keras.layers import Dense ,Activation,MaxPool1D,Conv1D,Flatten,Dropout,Activation,Dropout,Input,Lambda,concatenate
from keras.utils import np_utils
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
import nltk
import csv
import pandas as pd

from keras.preprocessing import text as keras_text, sequence as keras_seq

# %%
data = pd.read_csv('drive/My Drive/ML Internship IIIT Dharwad/train.csv')
pd.set_option('display.max_colwidth',80)
data.head()
# Out:
#    id  ...  is_duplicate
# 0   0  ...             0
# 1   1  ...             0
# 2   2  ...             0
# 3   3  ...             0
# 4   4  ...             0
#
# [5 rows x 6 columns]

# %%
data.shape
# Out:
# (404290, 6)

# %%
print(data.dtypes)
print(data['question1'].dtypes)
print(data['question2'].dtypes)
type(data['question1'])
# Out:
# id               int64
# qid1             int64
# qid2             int64
# question1       object
# question2       object
# is_duplicate     int64
# dtype: object
# object
# object
# pandas.core.series.Series

# %% [markdown]
# # Setting target or labelfor each input

# %%
label_oneDimension=data['is_duplicate']

# %%
label_oneDimension.head(2)
# Out:
# 0    0
# 1    0
# Name: is_duplicate, dtype: int64

# %%
import numpy as np
from keras.utils.np_utils import to_categorical
label_twoDimension = to_categorical(data['is_duplicate'], num_classes=2)

# %%
label_twoDimension[0:1]
# Out:
# array([[1., 0.]], dtype=float32)

# %%
question_one=data['question1'].astype(str)
print(question_one.head())
# Out:
# 0              What is the step by step guide to invest in share market in india?
# 1                             What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 2       How can I increase the speed of my internet connection while using a VPN?
# 3                              Why am I mentally very lonely? How can I solve it?
# 4    Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
# Name: question1, dtype: object

# %%
question_two=data['question2'].astype(str)
print(question_two.head())
# Out:
# 0                          What is the step by step guide to invest in share market?
# 1    What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) d...
# 2                        How can Internet speed be increased by hacking through DNS?
# 3                  Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# 4                                            Which fish would survive in salt water?
# Name: question2, dtype: object

# %% [markdown]
# # Reading test data and preprocessing

# %%
#Data reading
'''
data_test = pd.read_csv('drive/My Drive/Summer Internship 2020 July/My Test File/Sunil/test.csv')
data_test_sample=data_test.dropna()
#data_test_sample=data_test_sample.head(100)
data_test_sample.head()
'''
# Out:
# "\ndata_test = pd.read_csv('drive/My Drive/Summer Internship 2020 July/My Test File/Sunil/test.csv')\ndata_test_sample=data_test.dropna()\n#data_test_sample=data_test_sample.head(100)\ndata_test_sample.head()\n"

# %%
'''
question_one_test=data_test_sample['question1'].astype(str)
print(question_one_test.head())
'''
# Out:
# "\nquestion_one_test=data_test_sample['question1'].astype(str)\nprint(question_one_test.head())\n"

# %%
'''
question_two_test=data_test_sample['question2'].astype(str)
print(question_two_test.head())
'''
# Out:
# "\nquestion_two_test=data_test_sample['question2'].astype(str)\nprint(question_two_test.head())\n"

# %% [markdown]
# # Fitting text on a single tokenized object

# %%
from keras.preprocessing.text import Tokenizer
tok_all = Tokenizer(char_level = False)
tok_all.fit_on_texts(question_one+question_two)
#tok_all.fit_on_texts(question_one+question_two+question_one_test+question_two_test)

# %%
vocabulary_all=len(tok_all.word_counts)
print(vocabulary_all)
# Out:
# 96494

# %% [markdown]
# ## **Train data Sequencing and Encoding**

# %%
#Encoding question 1
encoded_q1=tok_all.texts_to_sequences(question_one)
print(question_one[0])
encoded_q1[0]
# Out:
# What is the step by step guide to invest in share market in india?
# [2, 3, 1, 1221, 57, 1221, 2581, 7, 575, 8, 763, 383, 8, 35]

# %%
#Encoding question 2
encoded_q2=tok_all.texts_to_sequences(question_two)
print(question_two[0])
encoded_q2[0]
# Out:
# What is the step by step guide to invest in share market?
# [2, 3, 1, 1221, 57, 1221, 2581, 7, 575, 8, 763, 383]

# %% [markdown]
# # Pre-Padding on Train data

# %%
#####Padding encoded sequence of words
from keras.preprocessing import sequence
max_length=100
padded_docs_q1 = sequence.pad_sequences(encoded_q1, maxlen=max_length, padding='pre')

# %%
#####Padding encoded sequence of words
from keras.preprocessing import sequence
max_length=100
padded_docs_q2 = sequence.pad_sequences(encoded_q2, maxlen=max_length, padding='pre')

# %% [markdown]
# # **Encoding on Test data**

# %%
'''
#Encoding question 1
encoded_q1_test=tok_all.texts_to_sequences(question_one_test)
print(question_one_test[0])
encoded_q1_test[0]
'''
# Out:
# '\n#Encoding question 1\nencoded_q1_test=tok_all.texts_to_sequences(question_one_test)\nprint(question_one_test[0])\nencoded_q1_test[0]\n'

# %%
'''#Encoding question 1
encoded_q2_test=tok_all.texts_to_sequences(question_two_test)
print(question_two_test[0])
encoded_q2_test[0]'''
# Out:
# '#Encoding question 1\nencoded_q2_test=tok_all.texts_to_sequences(question_two_test)\nprint(question_two_test[0])\nencoded_q2_test[0]'

# %% [markdown]
# # Pre-Padding on test data

# %%
'''#####Padding encoded sequence of words
padded_docs_q1_test = sequence.pad_sequences(encoded_q1_test, maxlen=max_length, padding='pre')
padded_docs_q2_test = sequence.pad_sequences(encoded_q2_test, maxlen=max_length, padding='pre')'''
# Out:
# "#####Padding encoded sequence of words\npadded_docs_q1_test = sequence.pad_sequences(encoded_q1_test, maxlen=max_length, padding='pre')\npadded_docs_q2_test = sequence.pad_sequences(encoded_q2_test, maxlen=max_length, padding='pre')"

# %% [markdown]
# # Reading Embedding Vector from Glove

# %%
# download pretrained GloVe embeddings
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2020-08-06 11:43:58--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-08-06 11:43:58--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-08-06 11:43:58--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  2.06MB/s    in 6m 52s
#
# 2020-08-06 11:50:50 (1.99 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
# !unzip glove.6B.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
import os
import numpy as np

# %%
glove_dir = './'

#load glove embedding into a dict

embeddings_index = {} #initialize dictionary
f = open(os.path.join(glove_dir, 'glove.6B.300d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
#create embedding matrix

embedding_matrix = np.zeros((vocabulary_all+1, 300))
for word, i in tok_all.word_index.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		# words not found in embedding index will be all-zeros.
		embedding_matrix[i] = embedding_vector

# %% [markdown]
# # Defining Input Shape for Model

# %%
Question1_shape= Input(shape=[max_length])
Question1_shape.shape
# Out:
# TensorShape([None, 100])

# %%
Question2_shape= Input(shape=[max_length])
Question2_shape.shape
# Out:
# TensorShape([None, 100])

# %% [markdown]
# # Embedding Layer

# %%
Embedding_Layer = Embedding(vocabulary_all+1,300,weights=[embedding_matrix], input_length=max_length, trainable=False)

# %% [markdown]
# # CNN Network

# %%
CNN4_network=Sequential([Embedding_Layer,
                        Conv1D(32,3,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(64,5,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Conv1D(32,3,activation="relu",padding='same'),
                       Dropout(0.2),
                       MaxPool1D(2),
                       Flatten(),
                       Dense(128,activation="linear"),
                       Dropout(0.3)
                       
                       ])

# %% [markdown]
# # Printing Model summary

# %%
CNN4_network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 300)          28948500
# _________________________________________________________________
# conv1d (Conv1D)              (None, 100, 32)           28832
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 32)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 50, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 50, 64)            10304
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 25, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 25, 64)            20544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 64)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 12, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 12, 32)            6176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 32)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 6, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# =================================================================
# Total params: 29,039,060
# Trainable params: 90,560
# Non-trainable params: 28,948,500
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(CNN4_network, to_file='CNN4_network.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## **create siamese network from CNN model and store output feature vectors**

# %%
Question1_CNN_feature=CNN4_network(Question1_shape)
Question2_CNN_feature=CNN4_network(Question2_shape)

# %% [markdown]
# # Adding and multiplying features obtained from Siamese CNN network

# %%
from keras import backend as K
from keras.optimizers import Adam

# %%
lamda_function=Lambda(lambda tensor:K.abs(tensor[0]-tensor[1]),name="Absolute_distance")
abs_distance_vector=lamda_function([Question1_CNN_feature,Question2_CNN_feature])

lamda_function2=Lambda(lambda tensor:K.abs(tensor[0]*tensor[1]),name="Hamadard_multiplication") #abs() returns absolute value
hamadard_vector=lamda_function2([Question1_CNN_feature,Question2_CNN_feature])

# %% [markdown]
# # Adding abs_distance_vector and hamadard_vector

# %%
from keras.layers import Add

# %%
added_vecotr = Add()([abs_distance_vector, hamadard_vector])

# %% [markdown]
# # Final Model prediction

# %%
predict=Dense(2,activation="sigmoid")(added_vecotr)

# %% [markdown]
# # Creating sequential model using Model() class and compilation

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score
Siamese4_Network=Model(inputs=[Question1_shape,Question2_shape],outputs=predict)
Siamese4_Network.compile(loss = "binary_crossentropy", optimizer=Adam(lr=0.00003), metrics=["accuracy"])

# %%
Siamese4_Network.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          29039060    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# Absolute_distance (Lambda)      (None, 128)          0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# Hamadard_multiplication (Lambda (None, 128)          0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128)          0           Absolute_distance[0][0]
#                                                                  Hamadard_multiplication[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            258         add[0][0]
# ==================================================================================================
# Total params: 29,039,318
# Trainable params: 90,818
# Non-trainable params: 28,948,500
# __________________________________________________________________________________________________

# %% [markdown]
# # Plot model

# %%
from keras.utils import plot_model
plot_model(Siamese4_Network, to_file='Siamese4_Network.png',show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Setting hyperparameter for training

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
earlystopper = EarlyStopping(patience=8, verbose=1)
#checkpointer = ModelCheckpoint(filepath = 'cnn_model_one_.{epoch:02d}-{val_loss:.6f}.hdf5',
 #                              verbose=1,
 #                              save_best_only=True, save_weights_only = True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9,
                              patience=2, min_lr=0.00001, verbose=1)

# %% [markdown]
# # Data split into train and validation set

# %%
# Splitting data into train and test
from sklearn.model_selection import train_test_split
q1_train, q1_val,q2_train, q2_val, label_train, label_val, label_oneD_train, label_oneD_val = train_test_split(padded_docs_q1,padded_docs_q2, label_twoDimension, label_oneDimension, test_size=0.30,
random_state=42)

# %% [markdown]
# # Model fitting or training

# %%
history = Siamese4_Network.fit([q1_train,q2_train],label_train,
                    batch_size=256,epochs=100,validation_data=([q1_val,q2_val],label_val),callbacks=[earlystopper, reduce_lr])
# Out:
# Epoch 1/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.6323 - accuracy: 0.6280 - val_loss: 0.6429 - val_accuracy: 0.6300
# Epoch 2/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.6033 - accuracy: 0.6597 - val_loss: 0.6229 - val_accuracy: 0.6789
# Epoch 3/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5796 - accuracy: 0.6977 - val_loss: 0.6137 - val_accuracy: 0.7039
# Epoch 4/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5660 - accuracy: 0.7087 - val_loss: 0.6053 - val_accuracy: 0.7097
# Epoch 5/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5570 - accuracy: 0.7162 - val_loss: 0.6003 - val_accuracy: 0.7176
# Epoch 6/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5504 - accuracy: 0.7203 - val_loss: 0.5945 - val_accuracy: 0.7214
# Epoch 7/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5449 - accuracy: 0.7247 - val_loss: 0.5888 - val_accuracy: 0.7226
# Epoch 8/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5399 - accuracy: 0.7283 - val_loss: 0.5852 - val_accuracy: 0.7288
# Epoch 9/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5357 - accuracy: 0.7315 - val_loss: 0.5811 - val_accuracy: 0.7278
# Epoch 10/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.5322 - accuracy: 0.7340 - val_loss: 0.5807 - val_accuracy: 0.7327
# Epoch 11/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5288 - accuracy: 0.7364 - val_loss: 0.5755 - val_accuracy: 0.7340
# Epoch 12/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5252 - accuracy: 0.7391 - val_loss: 0.5729 - val_accuracy: 0.7360
# Epoch 13/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5227 - accuracy: 0.7412 - val_loss: 0.5699 - val_accuracy: 0.7351
# Epoch 14/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5205 - accuracy: 0.7422 - val_loss: 0.5676 - val_accuracy: 0.7350
# Epoch 15/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5174 - accuracy: 0.7441 - val_loss: 0.5663 - val_accuracy: 0.7355
# Epoch 16/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5153 - accuracy: 0.7463 - val_loss: 0.5620 - val_accuracy: 0.7398
# Epoch 17/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5134 - accuracy: 0.7473 - val_loss: 0.5616 - val_accuracy: 0.7436
# Epoch 18/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5108 - accuracy: 0.7492 - val_loss: 0.5598 - val_accuracy: 0.7426
# Epoch 19/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5093 - accuracy: 0.7506 - val_loss: 0.5565 - val_accuracy: 0.7446
# Epoch 20/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5075 - accuracy: 0.7521 - val_loss: 0.5570 - val_accuracy: 0.7469
# Epoch 21/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.5056 - accuracy: 0.7529
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.699999931792263e-05.
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5056 - accuracy: 0.7529 - val_loss: 0.5568 - val_accuracy: 0.7442
# Epoch 22/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.5040 - accuracy: 0.7545 - val_loss: 0.5569 - val_accuracy: 0.7452
# Epoch 23/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5026 - accuracy: 0.7542 - val_loss: 0.5515 - val_accuracy: 0.7483
# Epoch 24/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5016 - accuracy: 0.7556 - val_loss: 0.5533 - val_accuracy: 0.7507
# Epoch 25/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.5000 - accuracy: 0.7567 - val_loss: 0.5503 - val_accuracy: 0.7499
# Epoch 26/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4985 - accuracy: 0.7572 - val_loss: 0.5523 - val_accuracy: 0.7465
# Epoch 27/100
# 1106/1106 [==============================] - 28s 25ms/step - loss: 0.4981 - accuracy: 0.7587 - val_loss: 0.5465 - val_accuracy: 0.7510
# Epoch 28/100
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.4964 - accuracy: 0.7587 - val_loss: 0.5470 - val_accuracy: 0.7522
# Epoch 29/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.7601
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.4300000040966553e-05.
# 1106/1106 [==============================] - 28s 26ms/step - loss: 0.4953 - accuracy: 0.7601 - val_loss: 0.5478 - val_accuracy: 0.7518
# Epoch 30/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4940 - accuracy: 0.7606 - val_loss: 0.5469 - val_accuracy: 0.7509
# Epoch 31/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4923 - accuracy: 0.7615 - val_loss: 0.5455 - val_accuracy: 0.7471
# Epoch 32/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4920 - accuracy: 0.7620 - val_loss: 0.5425 - val_accuracy: 0.7522
# Epoch 33/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4913 - accuracy: 0.7624 - val_loss: 0.5424 - val_accuracy: 0.7533
# Epoch 34/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4900 - accuracy: 0.7635 - val_loss: 0.5410 - val_accuracy: 0.7516
# Epoch 35/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4891 - accuracy: 0.7629 - val_loss: 0.5420 - val_accuracy: 0.7530
# Epoch 36/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4881 - accuracy: 0.7647
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 2.1869999545742758e-05.
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4881 - accuracy: 0.7647 - val_loss: 0.5412 - val_accuracy: 0.7531
# Epoch 37/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4882 - accuracy: 0.7646 - val_loss: 0.5401 - val_accuracy: 0.7575
# Epoch 38/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4871 - accuracy: 0.7648 - val_loss: 0.5377 - val_accuracy: 0.7558
# Epoch 39/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4856 - accuracy: 0.7661 - val_loss: 0.5365 - val_accuracy: 0.7556
# Epoch 40/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4852 - accuracy: 0.7666 - val_loss: 0.5361 - val_accuracy: 0.7575
# Epoch 41/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4847 - accuracy: 0.7664 - val_loss: 0.5359 - val_accuracy: 0.7581
# Epoch 42/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4843 - accuracy: 0.7669 - val_loss: 0.5359 - val_accuracy: 0.7555
# Epoch 43/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4828 - accuracy: 0.7677 - val_loss: 0.5353 - val_accuracy: 0.7580
# Epoch 44/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4823 - accuracy: 0.7674 - val_loss: 0.5371 - val_accuracy: 0.7551
# Epoch 45/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4815 - accuracy: 0.7685 - val_loss: 0.5343 - val_accuracy: 0.7545
# Epoch 46/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4809 - accuracy: 0.7686 - val_loss: 0.5355 - val_accuracy: 0.7555
# Epoch 47/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4797 - accuracy: 0.7693 - val_loss: 0.5319 - val_accuracy: 0.7565
# Epoch 48/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4800 - accuracy: 0.7697 - val_loss: 0.5325 - val_accuracy: 0.7580
# Epoch 49/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4795 - accuracy: 0.7702 - val_loss: 0.5315 - val_accuracy: 0.7594
# Epoch 50/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4796 - accuracy: 0.7692 - val_loss: 0.5327 - val_accuracy: 0.7558
# Epoch 51/100
# 1106/1106 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.7705
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.9682998936332296e-05.
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4787 - accuracy: 0.7705 - val_loss: 0.5319 - val_accuracy: 0.7566
# Epoch 52/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4774 - accuracy: 0.7716 - val_loss: 0.5310 - val_accuracy: 0.7595
# Epoch 53/100
# 1106/1106 [==============================] - 29s 27ms/step - loss: 0.4766 - accuracy: 0.7717 - val_loss: 0.5295 - val_accuracy: 0.7582
# Epoch 54/100
# 1106/1106 [==============================] - 29s 27ms/step - loss: 0.4762 - accuracy: 0.7722 - val_loss: 0.5296 - val_accuracy: 0.7600
# Epoch 55/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4757 - accuracy: 0.7719
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.7714698878990023e-05.
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4758 - accuracy: 0.7718 - val_loss: 0.5311 - val_accuracy: 0.7553
# Epoch 56/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4744 - accuracy: 0.7726 - val_loss: 0.5272 - val_accuracy: 0.7599
# Epoch 57/100
# 1106/1106 [==============================] - 29s 26ms/step - loss: 0.4741 - accuracy: 0.7729 - val_loss: 0.5277 - val_accuracy: 0.7591
# Epoch 58/100
# 1105/1106 [============================>.] - ETA: 0s - loss: 0.4735 - accuracy: 0.7734
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.5943229482218157e-05.
# 1106/1106 [==============================] - 29s 27ms/step - loss: 0.4735 - accuracy: 0.7734 - val_loss: 0.5293 - val_accuracy: 0.7594
# Epoch 59/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4736 - accuracy: 0.7737 - val_loss: 0.5265 - val_accuracy: 0.7612
# Epoch 60/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4726 - accuracy: 0.7737 - val_loss: 0.5276 - val_accuracy: 0.7599
# Epoch 61/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4725 - accuracy: 0.7732
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.4348906370287296e-05.
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4725 - accuracy: 0.7732 - val_loss: 0.5302 - val_accuracy: 0.7559
# Epoch 62/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4718 - accuracy: 0.7747 - val_loss: 0.5266 - val_accuracy: 0.7602
# Epoch 63/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4716 - accuracy: 0.7746
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.2914015405840473e-05.
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4715 - accuracy: 0.7747 - val_loss: 0.5268 - val_accuracy: 0.7590
# Epoch 64/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4715 - accuracy: 0.7744 - val_loss: 0.5266 - val_accuracy: 0.7603
# Epoch 65/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4716 - accuracy: 0.7744 - val_loss: 0.5249 - val_accuracy: 0.7612
# Epoch 66/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4709 - accuracy: 0.7751 - val_loss: 0.5246 - val_accuracy: 0.7620
# Epoch 67/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4705 - accuracy: 0.7751 - val_loss: 0.5257 - val_accuracy: 0.7614
# Epoch 68/100
# 1106/1106 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.7754
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.1622613783401903e-05.
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4707 - accuracy: 0.7754 - val_loss: 0.5248 - val_accuracy: 0.7603
# Epoch 69/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4697 - accuracy: 0.7758 - val_loss: 0.5245 - val_accuracy: 0.7591
# Epoch 70/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4696 - accuracy: 0.7760 - val_loss: 0.5234 - val_accuracy: 0.7616
# Epoch 71/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4690 - accuracy: 0.7763 - val_loss: 0.5218 - val_accuracy: 0.7632
# Epoch 72/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4683 - accuracy: 0.7764 - val_loss: 0.5222 - val_accuracy: 0.7621
# Epoch 73/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4682 - accuracy: 0.7770 - val_loss: 0.5217 - val_accuracy: 0.7628
# Epoch 74/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4681 - accuracy: 0.7758 - val_loss: 0.5224 - val_accuracy: 0.7615
# Epoch 75/100
# 1106/1106 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.7771
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.0460352405061712e-05.
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4670 - accuracy: 0.7771 - val_loss: 0.5219 - val_accuracy: 0.7632
# Epoch 76/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4682 - accuracy: 0.7761 - val_loss: 0.5220 - val_accuracy: 0.7623
# Epoch 77/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4682 - accuracy: 0.7770 - val_loss: 0.5201 - val_accuracy: 0.7643
# Epoch 78/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4667 - accuracy: 0.7777 - val_loss: 0.5218 - val_accuracy: 0.7630
# Epoch 79/100
# 1104/1106 [============================>.] - ETA: 0s - loss: 0.4670 - accuracy: 0.7774
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4670 - accuracy: 0.7774 - val_loss: 0.5227 - val_accuracy: 0.7620
# Epoch 80/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4665 - accuracy: 0.7774 - val_loss: 0.5204 - val_accuracy: 0.7635
# Epoch 81/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4664 - accuracy: 0.7769 - val_loss: 0.5220 - val_accuracy: 0.7639
# Epoch 82/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4661 - accuracy: 0.7779 - val_loss: 0.5198 - val_accuracy: 0.7641
# Epoch 83/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4662 - accuracy: 0.7777 - val_loss: 0.5226 - val_accuracy: 0.7611
# Epoch 84/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4659 - accuracy: 0.7779 - val_loss: 0.5210 - val_accuracy: 0.7619
# Epoch 85/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4657 - accuracy: 0.7771 - val_loss: 0.5207 - val_accuracy: 0.7630
# Epoch 86/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4649 - accuracy: 0.7788 - val_loss: 0.5213 - val_accuracy: 0.7623
# Epoch 87/100
# 1106/1106 [==============================] - 30s 28ms/step - loss: 0.4645 - accuracy: 0.7783 - val_loss: 0.5197 - val_accuracy: 0.7637
# Epoch 88/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4654 - accuracy: 0.7778 - val_loss: 0.5191 - val_accuracy: 0.7644
# Epoch 89/100
# 1106/1106 [==============================] - 30s 28ms/step - loss: 0.4648 - accuracy: 0.7778 - val_loss: 0.5202 - val_accuracy: 0.7614
# Epoch 90/100
# 1106/1106 [==============================] - 30s 28ms/step - loss: 0.4643 - accuracy: 0.7791 - val_loss: 0.5196 - val_accuracy: 0.7642
# Epoch 91/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4648 - accuracy: 0.7787 - val_loss: 0.5185 - val_accuracy: 0.7642
# Epoch 92/100
# 1106/1106 [==============================] - 30s 28ms/step - loss: 0.4651 - accuracy: 0.7783 - val_loss: 0.5194 - val_accuracy: 0.7636
# Epoch 93/100
# 1106/1106 [==============================] - 30s 27ms/step - loss: 0.4633 - accuracy: 0.7791 - val_loss: 0.5185 - val_accuracy: 0.7633
# Epoch 94/100
# 1106/1106 [==============================] - 30s 27ms/step - loss: 0.4634 - accuracy: 0.7788 - val_loss: 0.5175 - val_accuracy: 0.7648
# Epoch 95/100
# 1106/1106 [==============================] - 30s 28ms/step - loss: 0.4633 - accuracy: 0.7796 - val_loss: 0.5173 - val_accuracy: 0.7655
# Epoch 96/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4632 - accuracy: 0.7794 - val_loss: 0.5184 - val_accuracy: 0.7637
# Epoch 97/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4632 - accuracy: 0.7798 - val_loss: 0.5174 - val_accuracy: 0.7638
# Epoch 98/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4621 - accuracy: 0.7798 - val_loss: 0.5164 - val_accuracy: 0.7658
# Epoch 99/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4630 - accuracy: 0.7788 - val_loss: 0.5164 - val_accuracy: 0.7654
# Epoch 100/100
# 1106/1106 [==============================] - 31s 28ms/step - loss: 0.4623 - accuracy: 0.7794 - val_loss: 0.5167 - val_accuracy: 0.7645

# %% [markdown]
# # Model Prediction

# %%
Siamese4_Network_predictions = Siamese4_Network.predict([q1_val,q2_val])
#Siamese4_Network_predictions = Siamese4_Network.predict([padded_docs_q1_test,padded_docs_q2_test])

# %%
#Siamese4_Network_predictions_testData = Siamese4_Network.predict([padded_docs_q1_test,padded_docs_q1_test])

# %% [markdown]
# # Log loss

# %%
from sklearn.metrics import log_loss
log_loss_val= log_loss(label_val,Siamese4_Network_predictions)
log_loss_val
# Out:
# 0.5165067115568928

# %% [markdown]
# # Classification report

# %%
predictions = np.zeros_like(Siamese4_Network_predictions)
predictions[np.arange(len(Siamese4_Network_predictions)), Siamese4_Network_predictions.argmax(1)] = 1

# %%
predictionInteger=(np.argmax(predictions, axis=1))
#print('np.argmax(a, axis=1): {0}'.format(np.argmax(predictions, axis=1)))
predictionInteger
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import classification_report
print(classification_report(label_val,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83     76350
#            1       0.79      0.49      0.61     44937
#
#    micro avg       0.76      0.76      0.76    121287
#    macro avg       0.77      0.71      0.72    121287
# weighted avg       0.77      0.76      0.75    121287
#  samples avg       0.76      0.76      0.76    121287

# %%
from sklearn.metrics import precision_recall_fscore_support
print ("Precision, Recall, F1_score : macro ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='macro'))
print ("Precision, Recall, F1_score : micro ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='micro'))
print ("Precision, Recall, F1_score : weighted ",precision_recall_fscore_support(label_oneD_val,predictionInteger, average='weighted'))
# Out:
# Precision, Recall, F1_score : macro  (0.7748737669896946, 0.7084851894595241, 0.7197079410103634, None)
# Precision, Recall, F1_score : micro  (0.7645254643943704, 0.7645254643943704, 0.7645254643943704, None)
# Precision, Recall, F1_score : weighted  (0.7699172795394099, 0.7645254643943704, 0.748736433599114, None)

# %% [markdown]
# # Final train and val loss

# %%
min_val_loss = min(history.history["val_loss"])
min_train_loss = min(history.history["loss"])
max_val_acc = max(history.history["val_accuracy"])
max_train_acc = max(history.history["accuracy"])
print("min_train_loss=%g, min_val_loss=%g, max_train_acc=%g, max_val_acc=%g" % (min_train_loss,min_val_loss,max_train_acc,max_val_acc))
# Out:
# min_train_loss=0.462094, min_val_loss=0.516355, max_train_acc=0.779833, max_val_acc=0.76582

# %% [markdown]
# ## **Plot epoch Vs loss**

# %%
from matplotlib import pyplot as plt
plt.plot(history.history["loss"],color = 'red', label = 'train_loss')
plt.plot(history.history["val_loss"],color = 'blue', label = 'val_loss')
plt.title('Loss Visualisation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('4Layer_CNN_lossPlot_siamese.pdf',dpi=1000)

from google.colab import files
files.download('4Layer_CNN_lossPlot_siamese.pdf')

# %% [markdown]
# # Plot Epoch Vs Accuracy

# %%
plt.plot(history.history["accuracy"],color = 'red', label = 'train_accuracy')
plt.plot(history.history["val_accuracy"],color = 'blue', label = 'val_accuracy')
plt.title('Accuracy Visualisation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('4Layer_CNN_accuracyPlot_siamese.pdf',dpi=1000)
files.download('4Layer_CNN_accuracyPlot_siamese.pdf')

# %% [markdown]
# # Area Under Curve- ROC

# %%
#pred_test = Siamese4_Network.predict([padded_docs_q1_test,padded_docs_q2_test])
pred_train = Siamese4_Network.predict([q1_train,q2_train])
pred_val = Siamese4_Network.predict([q1_val,q2_val])

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

def plot_AUC_ROC(y_true, y_pred):
    n_classes = 2 #change this value according to class value

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
############################################################################################
    lw = 2
    # Compute macro-average ROC curve and ROC area

    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure()
    
    plt.plot(fpr["micro"], tpr["micro"],
            label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
            color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
            label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
            color='navy', linestyle=':', linewidth=4)
    
    colors = cycle(['aqua', 'darkorange'])
    #classes_list1 = ["DE","NE","DK"]
    classes_list1 = ["Non-duplicate","Duplicate"]
    for i, color,c in zip(range(n_classes), colors,classes_list1):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                label='{0} (AUC = {1:0.2f})'
                ''.format(c, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.legend(loc="lower right")
    #plt.show()
    plt.savefig('4Layer_CNN_RocPlot_siamese.pdf',dpi=1000)
    files.download('4Layer_CNN_RocPlot_siamese.pdf')

    # Plot of a ROC curve for a specific class
    '''
    plt.figure()
    lw = 2
    plt.plot(fpr[0], tpr[0], color='darkorange',
            lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[0])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
    '''

# %%
plot_AUC_ROC(label_val,pred_val)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score

# %%
auc_val = roc_auc_score(label_val,pred_val)
accuracy_val = accuracy_score(label_val,pred_val>0.5)
auc_train = roc_auc_score(label_train,pred_train)
accuracy_train = accuracy_score(label_train,pred_train>0.5)

print("auc_train=%g, auc_val=%g, accuracy_train=%g, accuracy_val=%g" % (auc_train, auc_val, accuracy_train, accuracy_val))
# Out:
# auc_train=0.856141, auc_val=0.827725, accuracy_train=0.782232, accuracy_val=0.761978

# %%
'''
fpr_train, tpr_train, thresholds_train = roc_curve(label_train,pred_train)
fpr_test, tpr_test, thresholds_test = roc_curve(label_val,pred_val)

#fpr_train, tpr_train, thresholds_train = roc_curve(label_oneD_train,pred_train_final)
#fpr_test, tpr_test, thresholds_test = roc_curve(label_oneD_val,pred_val_final)

plt.plot(fpr_train,tpr_train, color="blue", label="train roc, auc=%g" % (auc_train,))
plt.plot(fpr_test,tpr_test, color="green", label="val roc, auc=%g" % (auc_val,))

plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')
plt.savefig('AUC_CURVE_cnn4.pdf',dpi=1000)
#files.download('AUC_CURVE_cnn4.pdf')
'''
# Out:
# '\nfpr_train, tpr_train, thresholds_train = roc_curve(label_train,pred_train)\nfpr_test, tpr_test, thresholds_test = roc_curve(label_val,pred_val)\n\n#fpr_train, tpr_train, thresholds_train = roc_curve(label_oneD_train,pred_train_final)\n#fpr_test, tpr_test, thresholds_test = roc_curve(label_oneD_val,pred_val_final)\n\nplt.plot(fpr_train,tpr_train, color="blue", label="train roc, auc=%g" % (auc_train,))\nplt.plot(fpr_test,tpr_test, color="green", label="val roc, auc=%g" % (auc_val,))\n\nplt.plot([0,1], [0,1], color=\'orange\', linestyle=\'--\')\n\nplt.xticks(np.arange(0.0, 1.1, step=0.1))\nplt.xlabel("Flase Positive Rate", fontsize=15)\n\nplt.yticks(np.arange(0.0, 1.1, step=0.1))\nplt.ylabel("True Positive Rate", fontsize=15)\n\nplt.title(\'ROC Curve Analysis\', fontweight=\'bold\', fontsize=15)\nplt.legend(prop={\'size\':13}, loc=\'lower right\')\nplt.savefig(\'AUC_CURVE_cnn4.pdf\',dpi=1000)\n#files.download(\'AUC_CURVE_cnn4.pdf\')\n'
